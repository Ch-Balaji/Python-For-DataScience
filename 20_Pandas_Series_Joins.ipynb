# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Employee Information DataFrame with more records
df_employees = pd.DataFrame({
    'EmployeeID': [101, 102, 103, 104, 106],  # Added EmployeeID 106
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],  # Added Eve
    'Department': ['HR', 'Engineering', 'Finance', 'Marketing', 'HR']
})

df_employees
# Out:
#    EmployeeID     Name   Department
# 0         101    Alice           HR
# 1         102      Bob  Engineering
# 2         103  Charlie      Finance
# 3         104    David    Marketing
# 4         106      Eve           HR

# %%
# Employee Salary DataFrame with Name and more records
df_salaries = pd.DataFrame({
    'EmployeeID': [102, 103, 104, 105, 107],  # Added EmployeeID 107
    'Name': ['Bob', 'Charlie', 'David', 'Frank', 'Grace'],  # Added Frank and Grace
    'Salary': [70000, 80000, 90000, 60000, 75000]
})

df_salaries
# Out:
#    EmployeeID     Name  Salary
# 0         102      Bob   70000
# 1         103  Charlie   80000
# 2         104    David   90000
# 3         105    Frank   60000
# 4         107    Grace   75000

# %%
df_employees.merge(df_salaries)
# Out:
#    EmployeeID     Name   Department  Salary
# 0         102      Bob  Engineering   70000
# 1         103  Charlie      Finance   80000
# 2         104    David    Marketing   90000

# %%
df_employees.merge(df_salaries, on = 'EmployeeID')
# Out:
#    EmployeeID   Name_x   Department   Name_y  Salary
# 0         102      Bob  Engineering      Bob   70000
# 1         103  Charlie      Finance  Charlie   80000
# 2         104    David    Marketing    David   90000

# %%
df_employees.merge(df_salaries, on = ['EmployeeID', 'Name'])
# Out:
#    EmployeeID     Name   Department  Salary
# 0         102      Bob  Engineering   70000
# 1         103  Charlie      Finance   80000
# 2         104    David    Marketing   90000

# %%
pd.merge(df_employees, df_salaries)
# Out:
#    EmployeeID     Name   Department  Salary
# 0         102      Bob  Engineering   70000
# 1         103  Charlie      Finance   80000
# 2         104    David    Marketing   90000

# %%
pd.merge(df_employees, df_salaries, on = ['EmployeeID', 'Name'])
# Out:
#    EmployeeID     Name   Department  Salary
# 0         102      Bob  Engineering   70000
# 1         103  Charlie      Finance   80000
# 2         104    David    Marketing   90000

# %%
pd.merge(df_employees, df_salaries, on = ['EmployeeID', 'Name'], how = 'inner')
# Out:
#    EmployeeID     Name   Department  Salary
# 0         102      Bob  Engineering   70000
# 1         103  Charlie      Finance   80000
# 2         104    David    Marketing   90000

# %% [markdown]
# # Outer Merge

# %%
pd.merge(df_employees, df_salaries,  how = 'outer')
# Out:
#    EmployeeID     Name   Department   Salary
# 0         101    Alice           HR      NaN
# 1         102      Bob  Engineering  70000.0
# 2         103  Charlie      Finance  80000.0
# 3         104    David    Marketing  90000.0
# 4         106      Eve           HR      NaN
# 5         105    Frank          NaN  60000.0
# 6         107    Grace          NaN  75000.0

# %%
pd.merge(df_employees, df_salaries, on = ['EmployeeID'], how = 'outer')
# Out:
#    EmployeeID   Name_x   Department   Name_y   Salary
# 0         101    Alice           HR      NaN      NaN
# 1         102      Bob  Engineering      Bob  70000.0
# 2         103  Charlie      Finance  Charlie  80000.0
# 3         104    David    Marketing    David  90000.0
# 4         106      Eve           HR      NaN      NaN
# 5         105      NaN          NaN    Frank  60000.0
# 6         107      NaN          NaN    Grace  75000.0

# %%
pd.merge(df_employees, df_salaries, on = ['EmployeeID', 'Name'], how = 'outer')
# Out:
#    EmployeeID     Name   Department   Salary
# 0         101    Alice           HR      NaN
# 1         102      Bob  Engineering  70000.0
# 2         103  Charlie      Finance  80000.0
# 3         104    David    Marketing  90000.0
# 4         106      Eve           HR      NaN
# 5         105    Frank          NaN  60000.0
# 6         107    Grace          NaN  75000.0

# %% [markdown]
# # Left Merge

# %%
df_employees, df_salaries
# Out:
# (   EmployeeID     Name   Department
#  0         101    Alice           HR
#  1         102      Bob  Engineering
#  2         103  Charlie      Finance
#  3         104    David    Marketing
#  4         106      Eve           HR,
#     EmployeeID     Name  Salary
#  0         102      Bob   70000
#  1         103  Charlie   80000
#  2         104    David   90000
#  3         105    Frank   60000
#  4         107    Grace   75000)

# %%
pd.merge(df_employees, df_salaries,  how = 'left')
# Out:
#    EmployeeID     Name   Department   Salary
# 0         101    Alice           HR      NaN
# 1         102      Bob  Engineering  70000.0
# 2         103  Charlie      Finance  80000.0
# 3         104    David    Marketing  90000.0
# 4         106      Eve           HR      NaN

# %%
pd.merge(df_employees, df_salaries, on = ['EmployeeID'], how = 'left')
# Out:
#    EmployeeID   Name_x   Department   Name_y   Salary
# 0         101    Alice           HR      NaN      NaN
# 1         102      Bob  Engineering      Bob  70000.0
# 2         103  Charlie      Finance  Charlie  80000.0
# 3         104    David    Marketing    David  90000.0
# 4         106      Eve           HR      NaN      NaN

# %%
pd.merge(df_employees, df_salaries, on = ['EmployeeID', 'Name'], how = 'left')
# Out:
#    EmployeeID     Name   Department   Salary
# 0         101    Alice           HR      NaN
# 1         102      Bob  Engineering  70000.0
# 2         103  Charlie      Finance  80000.0
# 3         104    David    Marketing  90000.0
# 4         106      Eve           HR      NaN

# %% [markdown]
# # Right Merge

# %%
pd.merge(df_employees, df_salaries,  how = 'right')
# Out:
#    EmployeeID     Name   Department  Salary
# 0         102      Bob  Engineering   70000
# 1         103  Charlie      Finance   80000
# 2         104    David    Marketing   90000
# 3         105    Frank          NaN   60000
# 4         107    Grace          NaN   75000

# %%
pd.merge(df_employees, df_salaries, on = ['EmployeeID'], how = 'right')
# Out:
#    EmployeeID   Name_x   Department   Name_y  Salary
# 0         102      Bob  Engineering      Bob   70000
# 1         103  Charlie      Finance  Charlie   80000
# 2         104    David    Marketing    David   90000
# 3         105      NaN          NaN    Frank   60000
# 4         107      NaN          NaN    Grace   75000

# %%
pd.merge(df_employees, df_salaries, on = ['EmployeeID', 'Name'], how = 'right')
# Out:
#    EmployeeID     Name   Department  Salary
# 0         102      Bob  Engineering   70000
# 1         103  Charlie      Finance   80000
# 2         104    David    Marketing   90000
# 3         105    Frank          NaN   60000
# 4         107    Grace          NaN   75000

# %%
df_employees, df_salaries
# Out:
# (   EmployeeID     Name   Department
#  0         101    Alice           HR
#  1         102      Bob  Engineering
#  2         103  Charlie      Finance
#  3         104    David    Marketing
#  4         106      Eve           HR,
#     EmployeeID     Name  Salary
#  0         102      Bob   70000
#  1         103  Charlie   80000
#  2         104    David   90000
#  3         105    Frank   60000
#  4         107    Grace   75000)

# %% [markdown]
# # Cross Merge

# %%
pd.merge(df_employees, df_salaries,  how = 'cross')
# Out:
#     EmployeeID_x   Name_x   Department  EmployeeID_y   Name_y  Salary
# 0            101    Alice           HR           102      Bob   70000
# 1            101    Alice           HR           103  Charlie   80000
# 2            101    Alice           HR           104    David   90000
# 3            101    Alice           HR           105    Frank   60000
# 4            101    Alice           HR           107    Grace   75000
# 5            102      Bob  Engineering           102      Bob   70000
# 6            102      Bob  Engineering           103  Charlie   80000
# 7            102      Bob  Engineering           104    David   90000
# 8            102      Bob  Engineering           105    Frank   60000
# 9            102      Bob  Engineering           107    Grace   75000
# 10           103  Charlie      Finance           102      Bob   70000
# 11           103  Charlie      Finance           103  Charlie   80000
# ...

# %% [markdown]
# # Joins
#
# 1. Similar to Merge ( Not much of differnece )
# 2. Joins usually works better with indexes.
# 3. We used column names while merging
# 4. Same output as merge, but just a lot more work.

# %%
df_employees.join(df_salaries)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-b8b7b1fafe86> in <cell line: 1>()
# ----> 1 df_employees.join(df_salaries)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9977         5  K1  A5   B1
#    9978         """
# -> 9979         return self._join_compat(
#    9980             other,
#    9981             on=on,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10016                     validate=validate,
#   10017                 )
# > 10018             return merge(
#   10019                 self,
#   10020                 other,
#
# ...

# %%
df_employees.join(df_salaries, how = 'outer', on = ['EmployeeID'], lsuffix = 'left', rsuffix = 'right')
# Out:
#      EmployeeID  EmployeeIDleft Nameleft   Department  EmployeeIDright  \
# 0.0         101           101.0    Alice           HR              NaN
# 1.0         102           102.0      Bob  Engineering              NaN
# 2.0         103           103.0  Charlie      Finance              NaN
# 3.0         104           104.0    David    Marketing              NaN
# 4.0         106           106.0      Eve           HR              NaN
# NaN           0             NaN      NaN          NaN            102.0
# NaN           1             NaN      NaN          NaN            103.0
# NaN           2             NaN      NaN          NaN            104.0
# NaN           3             NaN      NaN          NaN            105.0
# NaN           4             NaN      NaN          NaN            107.0
#
#     Nameright   Salary
# 0.0       NaN      NaN
# 1.0       NaN      NaN
# 2.0       NaN      NaN
# 3.0       NaN      NaN
# 4.0       NaN      NaN
# NaN       Bob  70000.0
# ...

# %%
df4 = df_employees.set_index("EmployeeID")
df5 = df_salaries.set_index("EmployeeID")

# %%
df4.join(df5, how = 'outer', on = ['EmployeeID'], lsuffix = 'left', rsuffix = 'right')
# Out:
#        EmployeeID Nameleft   Department Nameright   Salary
# 101.0         101    Alice           HR       NaN      NaN
# 102.0         102      Bob  Engineering       Bob  70000.0
# 103.0         103  Charlie      Finance   Charlie  80000.0
# 104.0         104    David    Marketing     David  90000.0
# 106.0         106      Eve           HR       NaN      NaN
# NaN           105      NaN          NaN     Frank  60000.0
# NaN           107      NaN          NaN     Grace  75000.0

# %% [markdown]
# # Merging 3 dataframes

# %%
import pandas as pd

# Employee Information DataFrame
df_employees = pd.DataFrame({
    'EmployeeID': [101, 102, 103, 104],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'DeptID': [1, 2, 1, 3]
})

# Employee Salary DataFrame
df_salaries = pd.DataFrame({
    'EmployeeID': [101, 102, 103, 104],
    'Salary': [50000, 60000, 55000, 70000]
})

# Departments DataFrame
df_departments = pd.DataFrame({
    'DeptID': [1, 2, 3],
    'DeptName': ['HR', 'Engineering', 'Marketing']
})

# %%
df_employees
# Out:
#    EmployeeID     Name  DeptID
# 0         101    Alice       1
# 1         102      Bob       2
# 2         103  Charlie       1
# 3         104    David       3

# %%
df_salaries
# Out:
#    EmployeeID  Salary
# 0         101   50000
# 1         102   60000
# 2         103   55000
# 3         104   70000

# %%
df_departments
# Out:
#    DeptID     DeptName
# 0       1           HR
# 1       2  Engineering
# 2       3    Marketing

# %%
df_merged_1 = pd.merge(df_employees, df_salaries, on='EmployeeID')
df_final_merged = pd.merge(df_merged_1, df_departments, on='DeptID')
df_final_merged
# Out:
#    EmployeeID     Name  DeptID  Salary     DeptName
# 0         101    Alice       1   50000           HR
# 1         103  Charlie       1   55000           HR
# 2         102      Bob       2   60000  Engineering
# 3         104    David       3   70000    Marketing

# %% [markdown]
# # Concatenate
#
# 1. Putting one df below/above other.
# 2. Join and merge, puts dataframe side by side.

# %%
# Employee Information DataFrame with more records
df_employees = pd.DataFrame({
    'EmployeeID': [101, 102, 103, 104, 106],  # Added EmployeeID 106
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],  # Added Eve
    'Department': ['HR', 'Engineering', 'Finance', 'Marketing', 'HR']
})



# Employee Salary DataFrame with Name and more records
df_salaries = pd.DataFrame({
    'EmployeeID': [102, 103, 104, 105, 107],  # Added EmployeeID 107
    'Name': ['Bob', 'Charlie', 'David', 'Frank', 'Grace'],  # Added Frank and Grace
    'Salary': [70000, 80000, 90000, 60000, 75000]
})

# %%
pd.concat([df_employees, df_salaries])
# Out:
#    EmployeeID     Name   Department   Salary
# 0         101    Alice           HR      NaN
# 1         102      Bob  Engineering      NaN
# 2         103  Charlie      Finance      NaN
# 3         104    David    Marketing      NaN
# 4         106      Eve           HR      NaN
# 0         102      Bob          NaN  70000.0
# 1         103  Charlie          NaN  80000.0
# 2         104    David          NaN  90000.0
# 3         105    Frank          NaN  60000.0
# 4         107    Grace          NaN  75000.0

# %%
pd.concat([df_employees, df_salaries], axis = 1)
# Out:
#    EmployeeID     Name   Department  EmployeeID     Name  Salary
# 0         101    Alice           HR         102      Bob   70000
# 1         102      Bob  Engineering         103  Charlie   80000
# 2         103  Charlie      Finance         104    David   90000
# 3         104    David    Marketing         105    Frank   60000
# 4         106      Eve           HR         107    Grace   75000

# %%
pd.concat([df_employees, df_salaries], join = 'inner') # Only take the columns in to consideration
# Out:
#    EmployeeID     Name
# 0         101    Alice
# 1         102      Bob
# 2         103  Charlie
# 3         104    David
# 4         106      Eve
# 0         102      Bob
# 1         103  Charlie
# 2         104    David
# 3         105    Frank
# 4         107    Grace

# %%
pd.concat([df_employees, df_salaries], join = 'inner', axis = 1)
# Out:
#    EmployeeID     Name   Department  EmployeeID     Name  Salary
# 0         101    Alice           HR         102      Bob   70000
# 1         102      Bob  Engineering         103  Charlie   80000
# 2         103  Charlie      Finance         104    David   90000
# 3         104    David    Marketing         105    Frank   60000
# 4         106      Eve           HR         107    Grace   75000

# %% [markdown]
# # Append

# %%
df_employees.append(df_salaries)
# Out:
# <ipython-input-79-337058ee8e97>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_employees.append(df_salaries)
#    EmployeeID     Name   Department   Salary
# 0         101    Alice           HR      NaN
# 1         102      Bob  Engineering      NaN
# 2         103  Charlie      Finance      NaN
# 3         104    David    Marketing      NaN
# 4         106      Eve           HR      NaN
# 0         102      Bob          NaN  70000.0
# 1         103  Charlie          NaN  80000.0
# 2         104    David          NaN  90000.0
# 3         105    Frank          NaN  60000.0
# 4         107    Grace          NaN  75000.0

# %%
"families_multigen":{
    "minimum_percentage_watch_time" : 5,
    "channel_specific" : ['HRT1','HRT2','RTL','RTL2','NOVA_TV',
                          'DOMA_TV','YOUNG_CHILDREN',
                          'OLDER_CHILDREN','RTL_KOCKICA'],
    "group_watch_threshold" : 40,
    "minSupRatio" : 0.2, # 0.5 means 50%. 0<minSupRatio<1
    "filters" : wp_filters,
    "exclude" : [],
    "group_exclude_watch_threshold": 0,
    "columns_list" : df_cols
}

# %%
"families_wo_kids":{
    "minimum_percentage_watch_time" : 5,
    "channel_specific" : [],
    "group_watch_threshold": 0,
    "minSupRatio" : 0.2, # 0.5 means 50%. 0<minSupRatio<1
    "filters" : wp_filters,
    "exclude" : ['YOUNG_CHILDREN', 'OLDER_CHILDREN','RTL_KOCKICA'],
    "group_exclude_watch_threshold": 1,
    "columns_list" : df_cols
},

# %%
"families_w_younger_kids":{
        "minimum_percentage_watch_time" : 5,
        "channel_specific" : ['YOUNG_CHILDREN','RTL_KOCKICA'],
        "group_watch_threshold": 45,
        "minSupRatio" : 0.2, # 0.5 means 50%. 0<minSupRatio<1
        "filters" : wp_filters,
        "exclude" : [],
        "group_exclude_watch_threshold": 0,
        "columns_list" : df_cols
    },
