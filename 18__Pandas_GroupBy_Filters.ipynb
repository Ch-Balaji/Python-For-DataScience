# %% [markdown]
# # Importing Packages

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies_data.csv')
df
# Out:
#      star_rating       title content_rating      genre  duration  \
# 0            8.6     Movie 1              R      Crime       163
# 1            7.1     Movie 2             PG      Crime       104
# 2            7.7     Movie 3          PG-13     Horror       124
# 3            7.6     Movie 4             PG  Adventure       159
# 4            8.8     Movie 5             PG     Horror       136
# ..           ...         ...            ...        ...       ...
# 995          7.1   Movie 996             PG  Adventure       155
# 996          7.9   Movie 997          PG-13     Horror       110
# 997          8.1   Movie 998          PG-13  Adventure        98
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 0    ['Actor5', 'Actor4', 'Actor1']
# 1    ['Actor5', 'Actor1', 'Actor4']
# 2    ['Actor2', 'Actor5', 'Actor1']
# 3    ['Actor2', 'Actor1', 'Actor5']
# 4    ['Actor1', 'Actor3', 'Actor4']
# ..                              ...
# 995  ['Actor3', 'Actor5', 'Actor1']
# 996  ['Actor4', 'Actor3', 'Actor2']
# 997  ['Actor5', 'Actor4', 'Actor1']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [1000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     1000 non-null   float64
#  1   title           1000 non-null   object
#  2   content_rating  1000 non-null   object
#  3   genre           1000 non-null   object
#  4   duration        1000 non-null   int64
#  5   actors_list     1000 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 47.0+ KB

# %% [markdown]
# # Filtering Datasets

# %%
df[df['star_rating']>9]['title']
# Out:
#      star_rating       title content_rating      genre  duration  \
# 6            9.2     Movie 7              R     Action        95
# 24           9.4    Movie 25              R     Comedy       165
# 28           9.1    Movie 29             PG  Adventure       168
# 33           9.4    Movie 34             PG     Comedy       107
# 36           9.1    Movie 37              R  Adventure        97
# ..           ...         ...            ...        ...       ...
# 981          9.2   Movie 982              R     Horror       131
# 986          9.4   Movie 987              R     Action       101
# 994          9.4   Movie 995          PG-13     Horror        97
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 6    ['Actor4', 'Actor5', 'Actor3']
# 24   ['Actor1', 'Actor5', 'Actor3']
# 28   ['Actor3', 'Actor5', 'Actor2']
# 33   ['Actor1', 'Actor4', 'Actor2']
# 36   ['Actor5', 'Actor2', 'Actor4']
# ..                              ...
# 981  ['Actor4', 'Actor2', 'Actor1']
# 986  ['Actor1', 'Actor3', 'Actor2']
# 994  ['Actor2', 'Actor1', 'Actor4']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [194 rows x 6 columns]

# %%
df[df['star_rating']>9]['title']
# Out:
# 6         Movie 7
# 24       Movie 25
# 28       Movie 29
# 33       Movie 34
# 36       Movie 37
#           ...
# 981     Movie 982
# 986     Movie 987
# 994     Movie 995
# 998     Movie 999
# 999    Movie 1000
# Name: title, Length: 194, dtype: object

# %%
df[df['star_rating']<7.5]
# Out:
#      star_rating      title content_rating      genre  duration  \
# 1            7.1    Movie 2             PG      Crime       104
# 7            7.2    Movie 8          PG-13  Adventure       146
# 9            7.1   Movie 10              R      Crime       117
# 12           7.1   Movie 13              R     Horror       173
# 19           7.0   Movie 20              R     Horror       101
# ..           ...        ...            ...        ...       ...
# 980          7.2  Movie 981              R     Horror       146
# 982          7.3  Movie 983          PG-13     Action       124
# 989          7.4  Movie 990             PG     Comedy       117
# 991          7.2  Movie 992          PG-13  Adventure       152
# 995          7.1  Movie 996             PG  Adventure       155
#
#                         actors_list
# 1    ['Actor5', 'Actor1', 'Actor4']
# 7    ['Actor1', 'Actor5', 'Actor4']
# 9    ['Actor4', 'Actor2', 'Actor5']
# 12   ['Actor1', 'Actor3', 'Actor5']
# 19   ['Actor3', 'Actor5', 'Actor4']
# ..                              ...
# 980  ['Actor1', 'Actor3', 'Actor2']
# 982  ['Actor2', 'Actor3', 'Actor4']
# 989  ['Actor5', 'Actor1', 'Actor3']
# 991  ['Actor2', 'Actor3', 'Actor1']
# 995  ['Actor3', 'Actor5', 'Actor1']
#
# [161 rows x 6 columns]

# %%
np.where(df['star_rating']>9)
# Out:
# (array([  6,  24,  28,  33,  36,  38,  53,  60,  64,  71,  72,  76,  83,
#          86,  96,  98,  99, 109, 110, 114, 115, 127, 128, 129, 132, 133,
#         143, 150, 163, 164, 170, 182, 186, 193, 195, 198, 199, 200, 201,
#         202, 209, 214, 215, 220, 227, 229, 236, 243, 254, 255, 259, 260,
#         261, 264, 267, 273, 285, 286, 299, 300, 302, 307, 309, 310, 315,
#         319, 320, 321, 323, 327, 329, 334, 335, 345, 346, 350, 352, 354,
#         356, 369, 379, 388, 390, 403, 418, 433, 437, 441, 443, 444, 448,
#         450, 475, 478, 484, 485, 515, 520, 526, 541, 546, 554, 557, 564,
#         565, 567, 569, 573, 581, 582, 584, 590, 595, 599, 630, 640, 644,
#         646, 652, 654, 662, 671, 672, 677, 693, 697, 701, 702, 712, 721,
#         722, 724, 725, 732, 741, 745, 751, 754, 765, 769, 776, 777, 780,
#         785, 786, 790, 792, 793, 797, 799, 803, 823, 824, 829, 830, 839,
#         843, 844, 845, 850, 854, 855, 860, 863, 874, 877, 884, 893, 900,
#         902, 911, 921, 923, 935, 937, 938, 940, 946, 948, 949, 951, 952,
#         962, 963, 967, 969, 972, 973, 977, 981, 986, 994, 998, 999]),)

# %%
df.loc[np.where(df['star_rating']>9)]
# Out:
#      star_rating       title content_rating      genre  duration  \
# 6            9.2     Movie 7              R     Action        95
# 24           9.4    Movie 25              R     Comedy       165
# 28           9.1    Movie 29             PG  Adventure       168
# 33           9.4    Movie 34             PG     Comedy       107
# 36           9.1    Movie 37              R  Adventure        97
# ..           ...         ...            ...        ...       ...
# 981          9.2   Movie 982              R     Horror       131
# 986          9.4   Movie 987              R     Action       101
# 994          9.4   Movie 995          PG-13     Horror        97
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 6    ['Actor4', 'Actor5', 'Actor3']
# 24   ['Actor1', 'Actor5', 'Actor3']
# 28   ['Actor3', 'Actor5', 'Actor2']
# 33   ['Actor1', 'Actor4', 'Actor2']
# 36   ['Actor5', 'Actor2', 'Actor4']
# ..                              ...
# 981  ['Actor4', 'Actor2', 'Actor1']
# 986  ['Actor1', 'Actor3', 'Actor2']
# 994  ['Actor2', 'Actor1', 'Actor4']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [194 rows x 6 columns]

# %%
df

# %% [markdown]
# # And condition()

# %%
df[(df['star_rating']>9) & (df['duration']>150)]
# Out:
#      star_rating       title content_rating      genre  duration  \
# 24           9.4    Movie 25              R     Comedy       165
# 28           9.1    Movie 29             PG  Adventure       168
# 72           9.2    Movie 73             PG     Horror       170
# 96           9.5    Movie 97             PG  Adventure       158
# 109          9.4   Movie 110          PG-13      Crime       162
# 110          9.2   Movie 111              R     Action       152
# 128          9.2   Movie 129          PG-13     Horror       173
# 133          9.4   Movie 134          PG-13     Horror       173
# 143          9.2   Movie 144             PG     Comedy       170
# 150          9.5   Movie 151             PG     Horror       180
# 164          9.1   Movie 165          PG-13     Comedy       179
# 170          9.3   Movie 171             PG     Comedy       151
# 199          9.1   Movie 200          PG-13     Horror       168
# 200          9.4   Movie 201              R     Horror       177
# 215          9.5   Movie 216          PG-13     Horror       172
# 220          9.4   Movie 221          PG-13      Crime       166
# 229          9.4   Movie 230              R  Adventure       167
# 243          9.3   Movie 244              R     Comedy       166
# 254          9.5   Movie 255             PG     Horror       159
# 255          9.5   Movie 256             PG      Crime       177
# 260          9.2   Movie 261             PG     Action       165
# 286          9.1   Movie 287          PG-13  Adventure       155
# 299          9.2   Movie 300             PG     Action       179
# 309          9.2   Movie 310             PG      Crime       167
# 319          9.3   Movie 320              R  Adventure       179
# 354          9.4   Movie 355             PG      Crime       163
# 388          9.4   Movie 389             PG     Action       156
# 403          9.3   Movie 404             PG  Adventure       162
# 441          9.5   Movie 442          PG-13     Comedy       156
# 443          9.4   Movie 444             PG     Horror       179
# 484          9.1   Movie 485          PG-13     Horror       158
# 569          9.1   Movie 570             PG  Adventure       168
# 573          9.4   Movie 574              R      Crime       172
# 590          9.1   Movie 591          PG-13     Action       159
# 595          9.2   Movie 596              R     Comedy       159
# 599          9.4   Movie 600             PG      Crime       154
# 640          9.4   Movie 641          PG-13     Action       162
# 646          9.2   Movie 647             PG     Action       159
# 654          9.1   Movie 655          PG-13     Action       167
# 671          9.2   Movie 672             PG     Horror       180
# 697          9.3   Movie 698          PG-13     Comedy       168
# 701          9.3   Movie 702          PG-13      Crime       165
# 721          9.4   Movie 722          PG-13      Crime       162
# 754          9.5   Movie 755              R     Horror       153
# 780          9.1   Movie 781              R  Adventure       160
# 785          9.1   Movie 786          PG-13     Horror       151
# 786          9.5   Movie 787              R     Comedy       180
# 823          9.1   Movie 824             PG      Crime       166
# 824          9.5   Movie 825          PG-13      Crime       151
# 830          9.2   Movie 831             PG  Adventure       171
# 839          9.4   Movie 840          PG-13  Adventure       174
# 843          9.1   Movie 844              R  Adventure       159
# 874          9.2   Movie 875             PG      Crime       156
# 877          9.3   Movie 878              R      Crime       177
# 923          9.3   Movie 924              R     Horror       169
# 946          9.4   Movie 947          PG-13  Adventure       163
# 962          9.1   Movie 963             PG     Action       178
# 973          9.3   Movie 974              R     Horror       152
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 24   ['Actor1', 'Actor5', 'Actor3']
# 28   ['Actor3', 'Actor5', 'Actor2']
# 72   ['Actor5', 'Actor3', 'Actor2']
# 96   ['Actor1', 'Actor5', 'Actor3']
# 109  ['Actor4', 'Actor3', 'Actor5']
# 110  ['Actor1', 'Actor3', 'Actor2']
# 128  ['Actor2', 'Actor4', 'Actor5']
# 133  ['Actor2', 'Actor1', 'Actor5']
# 143  ['Actor1', 'Actor2', 'Actor4']
# 150  ['Actor4', 'Actor2', 'Actor3']
# 164  ['Actor2', 'Actor3', 'Actor5']
# 170  ['Actor2', 'Actor3', 'Actor4']
# 199  ['Actor2', 'Actor1', 'Actor4']
# 200  ['Actor3', 'Actor1', 'Actor5']
# 215  ['Actor4', 'Actor3', 'Actor5']
# 220  ['Actor1', 'Actor5', 'Actor4']
# 229  ['Actor1', 'Actor2', 'Actor4']
# 243  ['Actor2', 'Actor3', 'Actor4']
# 254  ['Actor4', 'Actor1', 'Actor2']
# 255  ['Actor1', 'Actor3', 'Actor5']
# 260  ['Actor3', 'Actor4', 'Actor2']
# 286  ['Actor2', 'Actor4', 'Actor1']
# 299  ['Actor2', 'Actor4', 'Actor1']
# 309  ['Actor1', 'Actor2', 'Actor3']
# 319  ['Actor2', 'Actor3', 'Actor1']
# 354  ['Actor4', 'Actor1', 'Actor5']
# 388  ['Actor5', 'Actor1', 'Actor3']
# 403  ['Actor5', 'Actor3', 'Actor2']
# 441  ['Actor5', 'Actor4', 'Actor3']
# 443  ['Actor5', 'Actor3', 'Actor2']
# 484  ['Actor3', 'Actor1', 'Actor2']
# 569  ['Actor4', 'Actor5', 'Actor3']
# 573  ['Actor4', 'Actor5', 'Actor2']
# 590  ['Actor1', 'Actor3', 'Actor2']
# 595  ['Actor5', 'Actor2', 'Actor4']
# 599  ['Actor4', 'Actor3', 'Actor2']
# 640  ['Actor2', 'Actor1', 'Actor5']
# 646  ['Actor2', 'Actor3', 'Actor5']
# 654  ['Actor2', 'Actor5', 'Actor4']
# 671  ['Actor3', 'Actor4', 'Actor1']
# 697  ['Actor3', 'Actor1', 'Actor5']
# 701  ['Actor2', 'Actor5', 'Actor1']
# 721  ['Actor5', 'Actor3', 'Actor1']
# 754  ['Actor5', 'Actor3', 'Actor2']
# 780  ['Actor2', 'Actor3', 'Actor5']
# 785  ['Actor5', 'Actor3', 'Actor4']
# 786  ['Actor3', 'Actor5', 'Actor1']
# 823  ['Actor1', 'Actor5', 'Actor3']
# 824  ['Actor5', 'Actor4', 'Actor2']
# 830  ['Actor5', 'Actor4', 'Actor1']
# 839  ['Actor4', 'Actor5', 'Actor3']
# 843  ['Actor2', 'Actor5', 'Actor3']
# 874  ['Actor4', 'Actor2', 'Actor3']
# 877  ['Actor4', 'Actor1', 'Actor5']
# 923  ['Actor2', 'Actor4', 'Actor1']
# 946  ['Actor2', 'Actor3', 'Actor4']
# 962  ['Actor1', 'Actor2', 'Actor3']
# 973  ['Actor1', 'Actor3', 'Actor5']
# 999  ['Actor2', 'Actor5', 'Actor1']

# %%
df[(df['star_rating']<8)&(df['duration']>150)&(df['content_rating']=='R')]
# Out:
#      star_rating      title content_rating      genre  duration  \
# 12           7.1   Movie 13              R     Horror       173
# 25           7.8   Movie 26              R      Crime       178
# 27           7.2   Movie 28              R      Crime       180
# 41           7.1   Movie 42              R  Adventure       166
# 45           7.6   Movie 46              R     Horror       180
# 50           7.9   Movie 51              R     Action       155
# 51           7.5   Movie 52              R     Action       176
# 69           7.7   Movie 70              R  Adventure       163
# 139          7.3  Movie 140              R  Adventure       173
# 148          7.5  Movie 149              R     Comedy       173
# 154          7.3  Movie 155              R  Adventure       151
# 160          7.2  Movie 161              R     Horror       177
# 168          7.5  Movie 169              R     Comedy       178
# 188          7.5  Movie 189              R      Crime       162
# 207          7.1  Movie 208              R  Adventure       165
# 219          7.7  Movie 220              R      Crime       166
# 228          7.4  Movie 229              R  Adventure       156
# 271          7.7  Movie 272              R      Crime       154
# 313          7.3  Movie 314              R     Action       174
# 324          7.1  Movie 325              R     Horror       156
# 339          7.8  Movie 340              R      Crime       163
# 344          7.8  Movie 345              R  Adventure       155
# 405          7.4  Movie 406              R     Action       169
# 422          7.5  Movie 423              R     Action       178
# 497          7.4  Movie 498              R     Action       179
# 509          7.9  Movie 510              R     Horror       176
# 517          7.2  Movie 518              R     Horror       160
# 542          7.3  Movie 543              R     Horror       172
# 552          7.3  Movie 553              R  Adventure       163
# 594          7.9  Movie 595              R  Adventure       151
# 598          7.0  Movie 599              R     Horror       162
# 635          7.6  Movie 636              R  Adventure       165
# 658          7.1  Movie 659              R      Crime       151
# 681          7.4  Movie 682              R      Crime       165
# 733          7.5  Movie 734              R     Action       180
# 742          7.8  Movie 743              R     Comedy       178
# 763          7.5  Movie 764              R     Comedy       177
# 867          7.9  Movie 868              R     Horror       159
# 886          7.4  Movie 887              R     Action       154
# 888          7.9  Movie 889              R  Adventure       156
# 925          7.8  Movie 926              R     Horror       156
# 944          7.8  Movie 945              R     Comedy       173
#
#                         actors_list
# 12   ['Actor1', 'Actor3', 'Actor5']
# 25   ['Actor3', 'Actor5', 'Actor2']
# 27   ['Actor3', 'Actor5', 'Actor4']
# 41   ['Actor3', 'Actor2', 'Actor5']
# 45   ['Actor3', 'Actor5', 'Actor4']
# 50   ['Actor4', 'Actor3', 'Actor2']
# 51   ['Actor1', 'Actor2', 'Actor5']
# 69   ['Actor5', 'Actor3', 'Actor1']
# 139  ['Actor5', 'Actor1', 'Actor4']
# 148  ['Actor3', 'Actor5', 'Actor4']
# 154  ['Actor4', 'Actor2', 'Actor3']
# 160  ['Actor2', 'Actor5', 'Actor3']
# 168  ['Actor5', 'Actor3', 'Actor4']
# 188  ['Actor1', 'Actor5', 'Actor3']
# 207  ['Actor3', 'Actor2', 'Actor1']
# 219  ['Actor2', 'Actor3', 'Actor4']
# 228  ['Actor2', 'Actor3', 'Actor4']
# 271  ['Actor5', 'Actor1', 'Actor2']
# 313  ['Actor3', 'Actor2', 'Actor5']
# 324  ['Actor5', 'Actor4', 'Actor1']
# 339  ['Actor1', 'Actor4', 'Actor3']
# 344  ['Actor3', 'Actor5', 'Actor4']
# 405  ['Actor2', 'Actor3', 'Actor5']
# 422  ['Actor2', 'Actor5', 'Actor3']
# 497  ['Actor2', 'Actor3', 'Actor5']
# 509  ['Actor3', 'Actor5', 'Actor1']
# 517  ['Actor1', 'Actor5', 'Actor3']
# 542  ['Actor5', 'Actor4', 'Actor3']
# 552  ['Actor1', 'Actor5', 'Actor4']
# 594  ['Actor5', 'Actor1', 'Actor2']
# 598  ['Actor5', 'Actor1', 'Actor4']
# 635  ['Actor4', 'Actor1', 'Actor5']
# 658  ['Actor4', 'Actor3', 'Actor2']
# 681  ['Actor5', 'Actor4', 'Actor3']
# 733  ['Actor5', 'Actor4', 'Actor3']
# 742  ['Actor2', 'Actor3', 'Actor5']
# 763  ['Actor3', 'Actor2', 'Actor5']
# 867  ['Actor1', 'Actor3', 'Actor4']
# 886  ['Actor1', 'Actor2', 'Actor3']
# 888  ['Actor4', 'Actor2', 'Actor3']
# 925  ['Actor4', 'Actor2', 'Actor3']
# 944  ['Actor3', 'Actor2', 'Actor1']

# %% [markdown]
# # OR condition()

# %%
df[(df['star_rating']>9)|(df['duration']>200)]
# Out:
#      star_rating       title content_rating      genre  duration  \
# 6            9.2     Movie 7              R     Action        95
# 24           9.4    Movie 25              R     Comedy       165
# 28           9.1    Movie 29             PG  Adventure       168
# 33           9.4    Movie 34             PG     Comedy       107
# 36           9.1    Movie 37              R  Adventure        97
# ..           ...         ...            ...        ...       ...
# 981          9.2   Movie 982              R     Horror       131
# 986          9.4   Movie 987              R     Action       101
# 994          9.4   Movie 995          PG-13     Horror        97
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 6    ['Actor4', 'Actor5', 'Actor3']
# 24   ['Actor1', 'Actor5', 'Actor3']
# 28   ['Actor3', 'Actor5', 'Actor2']
# 33   ['Actor1', 'Actor4', 'Actor2']
# 36   ['Actor5', 'Actor2', 'Actor4']
# ..                              ...
# 981  ['Actor4', 'Actor2', 'Actor1']
# 986  ['Actor1', 'Actor3', 'Actor2']
# 994  ['Actor2', 'Actor1', 'Actor4']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [194 rows x 6 columns]

# %%
df[((df['star_rating']>9)&(df['content_rating']=='R'))|((df['genre']=='Adventure')&(df['duration']>200))]
# Out:
#      star_rating      title content_rating      genre  duration  \
# 6            9.2    Movie 7              R     Action        95
# 24           9.4   Movie 25              R     Comedy       165
# 36           9.1   Movie 37              R  Adventure        97
# 53           9.3   Movie 54              R  Adventure       107
# 60           9.5   Movie 61              R     Comedy       106
# 71           9.4   Movie 72              R     Action       124
# 110          9.2  Movie 111              R     Action       152
# 127          9.3  Movie 128              R     Comedy       106
# 193          9.3  Movie 194              R      Crime       146
# 200          9.4  Movie 201              R     Horror       177
# 201          9.3  Movie 202              R     Action       146
# 202          9.1  Movie 203              R     Comedy       117
# 214          9.4  Movie 215              R      Crime       125
# 227          9.1  Movie 228              R     Horror       116
# 229          9.4  Movie 230              R  Adventure       167
# 243          9.3  Movie 244              R     Comedy       166
# 261          9.2  Movie 262              R      Crime        98
# 285          9.3  Movie 286              R     Comedy       100
# 302          9.1  Movie 303              R      Crime        97
# 319          9.3  Movie 320              R  Adventure       179
# 327          9.3  Movie 328              R     Horror       111
# 346          9.4  Movie 347              R      Crime        97
# 437          9.1  Movie 438              R      Crime       125
# 448          9.1  Movie 449              R  Adventure       102
# 554          9.1  Movie 555              R      Crime       140
# 565          9.1  Movie 566              R     Horror       125
# 567          9.4  Movie 568              R      Crime       109
# 573          9.4  Movie 574              R      Crime       172
# 582          9.1  Movie 583              R     Comedy       139
# 584          9.2  Movie 585              R  Adventure       143
# 595          9.2  Movie 596              R     Comedy       159
# 722          9.1  Movie 723              R     Comedy       103
# 725          9.5  Movie 726              R      Crime       132
# 732          9.3  Movie 733              R     Action       101
# 754          9.5  Movie 755              R     Horror       153
# 765          9.3  Movie 766              R     Comedy       110
# 769          9.4  Movie 770              R     Comedy       127
# 780          9.1  Movie 781              R  Adventure       160
# 786          9.5  Movie 787              R     Comedy       180
# 797          9.3  Movie 798              R     Horror       116
# 799          9.1  Movie 800              R      Crime       142
# 843          9.1  Movie 844              R  Adventure       159
# 844          9.1  Movie 845              R     Action       139
# 845          9.1  Movie 846              R     Horror       113
# 854          9.3  Movie 855              R     Horror       149
# 877          9.3  Movie 878              R      Crime       177
# 900          9.5  Movie 901              R     Horror        95
# 923          9.3  Movie 924              R     Horror       169
# 949          9.2  Movie 950              R  Adventure        94
# 951          9.4  Movie 952              R  Adventure       125
# 952          9.4  Movie 953              R     Horror       141
# 967          9.2  Movie 968              R      Crime       137
# 973          9.3  Movie 974              R     Horror       152
# 981          9.2  Movie 982              R     Horror       131
# 986          9.4  Movie 987              R     Action       101
#
#                         actors_list
# 6    ['Actor4', 'Actor5', 'Actor3']
# 24   ['Actor1', 'Actor5', 'Actor3']
# 36   ['Actor5', 'Actor2', 'Actor4']
# 53   ['Actor5', 'Actor4', 'Actor1']
# 60   ['Actor1', 'Actor2', 'Actor3']
# 71   ['Actor3', 'Actor4', 'Actor5']
# 110  ['Actor1', 'Actor3', 'Actor2']
# 127  ['Actor5', 'Actor1', 'Actor4']
# 193  ['Actor2', 'Actor1', 'Actor4']
# 200  ['Actor3', 'Actor1', 'Actor5']
# 201  ['Actor5', 'Actor3', 'Actor2']
# 202  ['Actor5', 'Actor3', 'Actor1']
# 214  ['Actor3', 'Actor4', 'Actor1']
# 227  ['Actor1', 'Actor5', 'Actor4']
# 229  ['Actor1', 'Actor2', 'Actor4']
# 243  ['Actor2', 'Actor3', 'Actor4']
# 261  ['Actor3', 'Actor5', 'Actor4']
# 285  ['Actor4', 'Actor3', 'Actor1']
# 302  ['Actor2', 'Actor5', 'Actor4']
# 319  ['Actor2', 'Actor3', 'Actor1']
# 327  ['Actor5', 'Actor1', 'Actor4']
# 346  ['Actor5', 'Actor4', 'Actor1']
# 437  ['Actor1', 'Actor4', 'Actor5']
# 448  ['Actor2', 'Actor3', 'Actor5']
# 554  ['Actor1', 'Actor3', 'Actor4']
# 565  ['Actor2', 'Actor5', 'Actor3']
# 567  ['Actor2', 'Actor4', 'Actor5']
# 573  ['Actor4', 'Actor5', 'Actor2']
# 582  ['Actor3', 'Actor2', 'Actor1']
# 584  ['Actor5', 'Actor4', 'Actor3']
# 595  ['Actor5', 'Actor2', 'Actor4']
# 722  ['Actor1', 'Actor3', 'Actor2']
# 725  ['Actor4', 'Actor2', 'Actor1']
# 732  ['Actor5', 'Actor3', 'Actor1']
# 754  ['Actor5', 'Actor3', 'Actor2']
# 765  ['Actor3', 'Actor1', 'Actor4']
# 769  ['Actor4', 'Actor3', 'Actor2']
# 780  ['Actor2', 'Actor3', 'Actor5']
# 786  ['Actor3', 'Actor5', 'Actor1']
# 797  ['Actor5', 'Actor2', 'Actor1']
# 799  ['Actor3', 'Actor4', 'Actor2']
# 843  ['Actor2', 'Actor5', 'Actor3']
# 844  ['Actor4', 'Actor3', 'Actor2']
# 845  ['Actor2', 'Actor3', 'Actor4']
# 854  ['Actor3', 'Actor2', 'Actor1']
# 877  ['Actor4', 'Actor1', 'Actor5']
# 900  ['Actor5', 'Actor3', 'Actor2']
# 923  ['Actor2', 'Actor4', 'Actor1']
# 949  ['Actor4', 'Actor2', 'Actor1']
# 951  ['Actor5', 'Actor2', 'Actor4']
# 952  ['Actor4', 'Actor1', 'Actor3']
# 967  ['Actor4', 'Actor2', 'Actor1']
# 973  ['Actor1', 'Actor3', 'Actor5']
# 981  ['Actor4', 'Actor2', 'Actor1']
# 986  ['Actor1', 'Actor3', 'Actor2']

# %% [markdown]
# # isin function()

# %%
list1 = ['R',  'UNRATED']

# %%
df[df['content_rating'].isin(list1)]
# Out:
#      star_rating      title content_rating   genre  duration  \
# 0            8.6    Movie 1              R   Crime       163
# 6            9.2    Movie 7              R  Action        95
# 9            7.1   Movie 10              R   Crime       117
# 10           7.5   Movie 11              R   Crime       144
# 12           7.1   Movie 13              R  Horror       173
# ..           ...        ...            ...     ...       ...
# 981          9.2  Movie 982              R  Horror       131
# 986          9.4  Movie 987              R  Action       101
# 987          8.0  Movie 988              R  Comedy       114
# 992          8.2  Movie 993              R  Comedy       156
# 993          8.0  Movie 994              R  Action       137
#
#                         actors_list
# 0    ['Actor5', 'Actor4', 'Actor1']
# 6    ['Actor4', 'Actor5', 'Actor3']
# 9    ['Actor4', 'Actor2', 'Actor5']
# 10   ['Actor5', 'Actor3', 'Actor2']
# 12   ['Actor1', 'Actor3', 'Actor5']
# ..                              ...
# 981  ['Actor4', 'Actor2', 'Actor1']
# 986  ['Actor1', 'Actor3', 'Actor2']
# 987  ['Actor4', 'Actor1', 'Actor3']
# 992  ['Actor2', 'Actor1', 'Actor4']
# 993  ['Actor4', 'Actor5', 'Actor1']
#
# [321 rows x 6 columns]

# %%
df.loc[np.where(df['content_rating'].isin(list1))]
# Out:
#      star_rating      title content_rating   genre  duration  \
# 0            8.6    Movie 1              R   Crime       163
# 6            9.2    Movie 7              R  Action        95
# 9            7.1   Movie 10              R   Crime       117
# 10           7.5   Movie 11              R   Crime       144
# 12           7.1   Movie 13              R  Horror       173
# ..           ...        ...            ...     ...       ...
# 981          9.2  Movie 982              R  Horror       131
# 986          9.4  Movie 987              R  Action       101
# 987          8.0  Movie 988              R  Comedy       114
# 992          8.2  Movie 993              R  Comedy       156
# 993          8.0  Movie 994              R  Action       137
#
#                         actors_list
# 0    ['Actor5', 'Actor4', 'Actor1']
# 6    ['Actor4', 'Actor5', 'Actor3']
# 9    ['Actor4', 'Actor2', 'Actor5']
# 10   ['Actor5', 'Actor3', 'Actor2']
# 12   ['Actor1', 'Actor3', 'Actor5']
# ..                              ...
# 981  ['Actor4', 'Actor2', 'Actor1']
# 986  ['Actor1', 'Actor3', 'Actor2']
# 987  ['Actor4', 'Actor1', 'Actor3']
# 992  ['Actor2', 'Actor1', 'Actor4']
# 993  ['Actor4', 'Actor5', 'Actor1']
#
# [321 rows x 6 columns]

# %% [markdown]
# # Not operator

# %%
df.genre.unique()
# Out:
# array(['Crime', 'Horror', 'Adventure', 'Action', 'Comedy'], dtype=object)

# %%
list1 = ['R', 'PG-13']
list2 = ['Crime', 'Action',  'Adventure']

df[~(df['content_rating'].isin(list1)|(df['genre'].isin(list2)))]
# Out:
#      star_rating      title content_rating   genre  duration  \
# 4            8.8    Movie 5             PG  Horror       136
# 15           8.4   Movie 16             PG  Comedy        94
# 23           7.4   Movie 24             PG  Horror       116
# 26           7.2   Movie 27             PG  Horror       134
# 33           9.4   Movie 34             PG  Comedy       107
# ..           ...        ...            ...     ...       ...
# 938          9.1  Movie 939             PG  Comedy       126
# 941          8.2  Movie 942             PG  Comedy       142
# 964          7.3  Movie 965             PG  Comedy        96
# 970          7.6  Movie 971             PG  Horror       128
# 989          7.4  Movie 990             PG  Comedy       117
#
#                         actors_list
# 4    ['Actor1', 'Actor3', 'Actor4']
# 15   ['Actor2', 'Actor5', 'Actor4']
# 23   ['Actor5', 'Actor4', 'Actor3']
# 26   ['Actor1', 'Actor4', 'Actor5']
# 33   ['Actor1', 'Actor4', 'Actor2']
# ..                              ...
# 938  ['Actor1', 'Actor2', 'Actor5']
# 941  ['Actor3', 'Actor4', 'Actor1']
# 964  ['Actor1', 'Actor3', 'Actor5']
# 970  ['Actor5', 'Actor2', 'Actor4']
# 989  ['Actor5', 'Actor1', 'Actor3']
#
# [137 rows x 6 columns]

# %% [markdown]
# # unique()

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Horror', 'Adventure', 'Action', 'Comedy'], dtype=object)

# %%
df['genre'].nunique()
# Out:
# 5

# %%
df['content_rating'].unique()
# Out:
# array(['R', 'PG', 'PG-13'], dtype=object)

# %% [markdown]
# # nunique()

# %%
df['genre'].nunique()

# %%
df['content_rating'].nunique()
# Out:
# 3

# %% [markdown]
# # value_counts()

# %%
df
# Out:
#      star_rating       title content_rating      genre  duration  \
# 0            8.6     Movie 1              R      Crime       163
# 1            7.1     Movie 2             PG      Crime       104
# 2            7.7     Movie 3          PG-13     Horror       124
# 3            7.6     Movie 4             PG  Adventure       159
# 4            8.8     Movie 5             PG     Horror       136
# ..           ...         ...            ...        ...       ...
# 995          7.1   Movie 996             PG  Adventure       155
# 996          7.9   Movie 997          PG-13     Horror       110
# 997          8.1   Movie 998          PG-13  Adventure        98
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 0    ['Actor5', 'Actor4', 'Actor1']
# 1    ['Actor5', 'Actor1', 'Actor4']
# 2    ['Actor2', 'Actor5', 'Actor1']
# 3    ['Actor2', 'Actor1', 'Actor5']
# 4    ['Actor1', 'Actor3', 'Actor4']
# ..                              ...
# 995  ['Actor3', 'Actor5', 'Actor1']
# 996  ['Actor4', 'Actor3', 'Actor2']
# 997  ['Actor5', 'Actor4', 'Actor1']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [1000 rows x 6 columns]

# %%
df['genre'].value_counts()
# Out:
# Horror       218
# Adventure    216
# Action       195
# Comedy       194
# Crime        177
# Name: genre, dtype: int64

# %%
df[df['genre']=='Action']
# Out:
#      star_rating      title content_rating   genre  duration  \
# 5            8.7    Movie 6          PG-13  Action       159
# 6            9.2    Movie 7              R  Action        95
# 20           9.0   Movie 21          PG-13  Action       146
# 30           9.0   Movie 31              R  Action       144
# 43           7.7   Movie 44              R  Action       111
# ..           ...        ...            ...     ...       ...
# 972          9.1  Movie 973          PG-13  Action       125
# 982          7.3  Movie 983          PG-13  Action       124
# 986          9.4  Movie 987              R  Action       101
# 990          8.0  Movie 991             PG  Action       142
# 993          8.0  Movie 994              R  Action       137
#
#                         actors_list
# 5    ['Actor2', 'Actor3', 'Actor5']
# 6    ['Actor4', 'Actor5', 'Actor3']
# 20   ['Actor3', 'Actor4', 'Actor2']
# 30   ['Actor5', 'Actor2', 'Actor1']
# 43   ['Actor3', 'Actor2', 'Actor5']
# ..                              ...
# 972  ['Actor2', 'Actor3', 'Actor1']
# 982  ['Actor2', 'Actor3', 'Actor4']
# 986  ['Actor1', 'Actor3', 'Actor2']
# 990  ['Actor3', 'Actor2', 'Actor4']
# 993  ['Actor4', 'Actor5', 'Actor1']
#
# [195 rows x 6 columns]

# %% [markdown]
# # groupby

# %%
df.groupby('genre')

# %% [markdown]
# # getgroup()

# %%
df['genre'].value_counts()
# Out:
# Horror       218
# Adventure    216
# Action       195
# Comedy       194
# Crime        177
# Name: genre, dtype: int64

# %%
df.groupby('genre').get_group('Adventure')
# Out:
#      star_rating      title content_rating      genre  duration  \
# 3            7.6    Movie 4             PG  Adventure       159
# 7            7.2    Movie 8          PG-13  Adventure       146
# 13           7.5   Movie 14             PG  Adventure       121
# 16           7.6   Movie 17             PG  Adventure       147
# 28           9.1   Movie 29             PG  Adventure       168
# ..           ...        ...            ...        ...       ...
# 984          8.7  Movie 985             PG  Adventure       167
# 991          7.2  Movie 992          PG-13  Adventure       152
# 995          7.1  Movie 996             PG  Adventure       155
# 997          8.1  Movie 998          PG-13  Adventure        98
# 998          9.4  Movie 999          PG-13  Adventure       129
#
#                         actors_list
# 3    ['Actor2', 'Actor1', 'Actor5']
# 7    ['Actor1', 'Actor5', 'Actor4']
# 13   ['Actor4', 'Actor1', 'Actor5']
# 16   ['Actor4', 'Actor1', 'Actor3']
# 28   ['Actor3', 'Actor5', 'Actor2']
# ..                              ...
# 984  ['Actor2', 'Actor1', 'Actor3']
# 991  ['Actor2', 'Actor3', 'Actor1']
# 995  ['Actor3', 'Actor5', 'Actor1']
# 997  ['Actor5', 'Actor4', 'Actor1']
# 998  ['Actor1', 'Actor5', 'Actor3']
#
# [216 rows x 6 columns]

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Horror', 'Adventure', 'Action', 'Comedy'], dtype=object)

# %%
df['content_rating'].unique()
# Out:
# array(['R', 'PG', 'PG-13'], dtype=object)

# %%
df
# Out:
#      star_rating       title content_rating      genre  duration  \
# 0            8.6     Movie 1              R      Crime       163
# 1            7.1     Movie 2             PG      Crime       104
# 2            7.7     Movie 3          PG-13     Horror       124
# 3            7.6     Movie 4             PG  Adventure       159
# 4            8.8     Movie 5             PG     Horror       136
# ..           ...         ...            ...        ...       ...
# 995          7.1   Movie 996             PG  Adventure       155
# 996          7.9   Movie 997          PG-13     Horror       110
# 997          8.1   Movie 998          PG-13  Adventure        98
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 0    ['Actor5', 'Actor4', 'Actor1']
# 1    ['Actor5', 'Actor1', 'Actor4']
# 2    ['Actor2', 'Actor5', 'Actor1']
# 3    ['Actor2', 'Actor1', 'Actor5']
# 4    ['Actor1', 'Actor3', 'Actor4']
# ..                              ...
# 995  ['Actor3', 'Actor5', 'Actor1']
# 996  ['Actor4', 'Actor3', 'Actor2']
# 997  ['Actor5', 'Actor4', 'Actor1']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [1000 rows x 6 columns]

# %%
df.groupby(['genre','content_rating']).get_group(('Comedy','PG-13'))
# Out:
#      star_rating      title content_rating   genre  duration  \
# 8            8.1    Movie 9          PG-13  Comedy       159
# 11           8.3   Movie 12          PG-13  Comedy       103
# 31           8.8   Movie 32          PG-13  Comedy       111
# 39           8.4   Movie 40          PG-13  Comedy       158
# 46           7.3   Movie 47          PG-13  Comedy       127
# ..           ...        ...            ...     ...       ...
# 921          9.1  Movie 922          PG-13  Comedy        91
# 929          7.2  Movie 930          PG-13  Comedy       109
# 933          7.3  Movie 934          PG-13  Comedy       164
# 961          8.5  Movie 962          PG-13  Comedy       132
# 968          8.4  Movie 969          PG-13  Comedy        92
#
#                         actors_list
# 8    ['Actor3', 'Actor4', 'Actor5']
# 11   ['Actor2', 'Actor3', 'Actor4']
# 31   ['Actor5', 'Actor4', 'Actor3']
# 39   ['Actor5', 'Actor2', 'Actor4']
# 46   ['Actor3', 'Actor4', 'Actor1']
# ..                              ...
# 921  ['Actor4', 'Actor5', 'Actor2']
# 929  ['Actor3', 'Actor1', 'Actor4']
# 933  ['Actor1', 'Actor5', 'Actor3']
# 961  ['Actor1', 'Actor4', 'Actor3']
# 968  ['Actor2', 'Actor4', 'Actor5']
#
# [64 rows x 6 columns]

# %% [markdown]
# # statistical functions on groupby

# %%
df.columns

# %%
df
# Out:
#      star_rating       title content_rating      genre  duration  \
# 0            8.6     Movie 1              R      Crime       163
# 1            7.1     Movie 2             PG      Crime       104
# 2            7.7     Movie 3          PG-13     Horror       124
# 3            7.6     Movie 4             PG  Adventure       159
# 4            8.8     Movie 5             PG     Horror       136
# ..           ...         ...            ...        ...       ...
# 995          7.1   Movie 996             PG  Adventure       155
# 996          7.9   Movie 997          PG-13     Horror       110
# 997          8.1   Movie 998          PG-13  Adventure        98
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 0    ['Actor5', 'Actor4', 'Actor1']
# 1    ['Actor5', 'Actor1', 'Actor4']
# 2    ['Actor2', 'Actor5', 'Actor1']
# 3    ['Actor2', 'Actor1', 'Actor5']
# 4    ['Actor1', 'Actor3', 'Actor4']
# ..                              ...
# 995  ['Actor3', 'Actor5', 'Actor1']
# 996  ['Actor4', 'Actor3', 'Actor2']
# 997  ['Actor5', 'Actor4', 'Actor1']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [1000 rows x 6 columns]

# %%
df[df['genre']=='Action'].sum()
# Out:
# star_rating                                                  1607.0
# title             Movie 6Movie 7Movie 21Movie 31Movie 44Movie 51...
# content_rating    PG-13RPG-13RRRRPGPGPG-13RPGPG-13PG-13PG-13RPGR...
# genre             ActionActionActionActionActionActionActionActi...
# duration                                                      26398
# actors_list       ['Actor2', 'Actor3', 'Actor5']['Actor4', 'Acto...
# dtype: object

# %%
df.groupby('genre').sum()
# Out:
# <ipython-input-86-2dd2916c3e03>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('genre').sum()
#            star_rating  duration
# genre
# Action          1607.0     26398
# Adventure       1784.9     28960
# Comedy          1601.1     25570
# Crime           1476.9     23684
# Horror          1812.9     29290

# %%
df.groupby('genre').agg({'duration':'sum'})
# Out:
#            duration
# genre
# Action        26398
# Adventure     28960
# Comedy        25570
# Crime         23684
# Horror        29290

# %%
df.groupby('genre').agg({'duration':'max'})
# Out:
#            duration
# genre
# Action          180
# Adventure       179
# Comedy          180
# Crime           180
# Horror          180

# %%
df.groupby('genre').mean('duration')
# Out:
#            star_rating    duration
# genre
# Action        8.241026  135.374359
# Adventure     8.263426  134.074074
# Comedy        8.253093  131.804124
# Crime         8.344068  133.807910
# Horror        8.316055  134.357798

# %%
df.groupby('genre')['duration'].mean().reset_index()
# Out:
#        genre    duration
# 0     Action  135.374359
# 1  Adventure  134.074074
# 2     Comedy  131.804124
# 3      Crime  133.807910
# 4     Horror  134.357798

# %%
df
# Out:
#      star_rating       title content_rating      genre  duration  \
# 0            8.6     Movie 1              R      Crime       163
# 1            7.1     Movie 2             PG      Crime       104
# 2            7.7     Movie 3          PG-13     Horror       124
# 3            7.6     Movie 4             PG  Adventure       159
# 4            8.8     Movie 5             PG     Horror       136
# ..           ...         ...            ...        ...       ...
# 995          7.1   Movie 996             PG  Adventure       155
# 996          7.9   Movie 997          PG-13     Horror       110
# 997          8.1   Movie 998          PG-13  Adventure        98
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 0    ['Actor5', 'Actor4', 'Actor1']
# 1    ['Actor5', 'Actor1', 'Actor4']
# 2    ['Actor2', 'Actor5', 'Actor1']
# 3    ['Actor2', 'Actor1', 'Actor5']
# 4    ['Actor1', 'Actor3', 'Actor4']
# ..                              ...
# 995  ['Actor3', 'Actor5', 'Actor1']
# 996  ['Actor4', 'Actor3', 'Actor2']
# 997  ['Actor5', 'Actor4', 'Actor1']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [1000 rows x 6 columns]

# %%
df.groupby(['genre','content_rating'])['title'].count()
# Out:
# genre      content_rating
# Action     PG                63
#            PG-13             76
#            R                 56
# Adventure  PG                74
#            PG-13             69
#            R                 73
# Comedy     PG                75
#            PG-13             64
#            R                 55
# Crime      PG                62
#            PG-13             54
#            R                 61
# Horror     PG                62
#            PG-13             80
#            R                 76
# Name: title, dtype: int64

# %%
df.groupby(['genre','content_rating'])['duration'].sum().reset_index().head(20)
# Out:
#         genre content_rating  duration
# 0      Action             PG      8387
# 1      Action          PG-13     10170
# 2      Action              R      7841
# 3   Adventure             PG     10009
# 4   Adventure          PG-13      8963
# 5   Adventure              R      9988
# 6      Comedy             PG      9862
# 7      Comedy          PG-13      8516
# 8      Comedy              R      7192
# 9       Crime             PG      8353
# 10      Crime          PG-13      7271
# 11      Crime              R      8060
# 12     Horror             PG      8330
# 13     Horror          PG-13     10611
# 14     Horror              R     10349

# %%
df.groupby('content_rating')['duration'].max().reset_index()
# Out:
#   content_rating  duration
# 0             PG       180
# 1          PG-13       180
# 2              R       180

# %%
df[(df['content_rating'] == 'PG-13') & (df['duration']==180)]

# %% [markdown]
# # agg function in groupby`

# %%
df.groupby('content_rating')['star_rating'].agg((np.mean,np.median,np.sum,np.max,np.min)).reset_index()

# %%
df.groupby('content_rating')['genre'].agg(pd.Series.mode).reset_index()

# %%
df
# Out:
#      star_rating       title content_rating      genre  duration  \
# 0            8.6     Movie 1              R      Crime       163
# 1            7.1     Movie 2             PG      Crime       104
# 2            7.7     Movie 3          PG-13     Horror       124
# 3            7.6     Movie 4             PG  Adventure       159
# 4            8.8     Movie 5             PG     Horror       136
# ..           ...         ...            ...        ...       ...
# 995          7.1   Movie 996             PG  Adventure       155
# 996          7.9   Movie 997          PG-13     Horror       110
# 997          8.1   Movie 998          PG-13  Adventure        98
# 998          9.4   Movie 999          PG-13  Adventure       129
# 999          9.1  Movie 1000          PG-13      Crime       180
#
#                         actors_list
# 0    ['Actor5', 'Actor4', 'Actor1']
# 1    ['Actor5', 'Actor1', 'Actor4']
# 2    ['Actor2', 'Actor5', 'Actor1']
# 3    ['Actor2', 'Actor1', 'Actor5']
# 4    ['Actor1', 'Actor3', 'Actor4']
# ..                              ...
# 995  ['Actor3', 'Actor5', 'Actor1']
# 996  ['Actor4', 'Actor3', 'Actor2']
# 997  ['Actor5', 'Actor4', 'Actor1']
# 998  ['Actor1', 'Actor5', 'Actor3']
# 999  ['Actor2', 'Actor5', 'Actor1']
#
# [1000 rows x 6 columns]

# %%
df.groupby('genre').agg({'star_rating':'mean','content_rating':'count'})
# Out:
#            star_rating  content_rating
# genre
# Action        8.241026             195
# Adventure     8.263426             216
# Comedy        8.253093             194
# Crime         8.344068             177
# Horror        8.316055             218

# %% [markdown]
# # aggregate function()

# %%
df.groupby('genre').aggregate({'star_rating':'mean','content_rating':'count'})
# Out:
#            star_rating  content_rating
# genre
# Action        8.241026             195
# Adventure     8.263426             216
# Comedy        8.253093             194
# Crime         8.344068             177
# Horror        8.316055             218

# %% [markdown]
# # sort in groupby

# %%
df.groupby('genre',sort=True).aggregate({'star_rating':'mean','content_rating':'count'})
# Out:
#            star_rating  content_rating
# genre
# Action        8.241026             195
# Adventure     8.263426             216
# Comedy        8.253093             194
# Crime         8.344068             177
# Horror        8.316055             218

# %%
df.groupby('genre',sort=False).aggregate({'star_rating':'mean','content_rating':'count'})
# Out:
#            star_rating  content_rating
# genre
# Crime         8.344068             177
# Horror        8.316055             218
# Adventure     8.263426             216
# Action        8.241026             195
# Comedy        8.253093             194

# %% [markdown]
# # ngroups()

# %%
df.groupby('genre').ngroups
# Out:
# 5

# %%
df.genre.nunique()
# Out:
# 5

# %% [markdown]
# # Size

# %%
df.groupby('genre').size()
# Out:
# genre
# Action       195
# Adventure    216
# Comedy       194
# Crime        177
# Horror       218
# dtype: int64

# %%
df.groupby('genre').agg({'duration':'count'})
# Out:
#            duration
# genre
# Action          195
# Adventure       216
# Comedy          194
# Crime           177
# Horror          218

# %%
df.groupby('genre')['title'].count()

# %%
df.genre.value_counts()

# %% [markdown]
# # Pivot Tables and Merging.
